# %%
# !mmvec paired-omics\
    --microbe-file ../data/matched-mmvec/micro.biom\
    --metabolite-file ../data/matched-mmvec/met.biom\
    --training-column 'stratified_test_labels'\
    --epochs 500\
    --batch-size 4000\
    --latent-dim 3\
    --summary-interval 20\
    --summary-dir ../results/mmvec/run-stats\
    --embeddings-file ../results/mmvec/embeddings.txt\
    --ranks-file ../results/mmvec/ranks.tsv\
    --ordination-file ../results/mmvec/ordination.txt
# Out:
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/biom/table.py:4068: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return constructor(mat, index=index, columns=columns)
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/pandas/core/sparse/frame.py:257: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   sparse_index=BlockIndex(N, blocs, blens),
# ...

# %%
# !mmvec paired-omics\
    --microbe-file ../data/matched-mmvec/met.biom\
    --metabolite-file ../data/matched-mmvec/micro.biom\
    --training-column 'stratified_test_labels'\
    --epochs 50\
    --batch-size 4000\
    --latent-dim 3\
    --summary-interval 20\
    --min-feature-count 10\
    --summary-dir ../results/mmvec-microbe/run-stats\
    --embeddings-file ../results/mmvec-microbe/embeddings\
    --ranks-file ../results/mmvec-microbe/ranks\
    --ordination-file ../results/mmvec-microbe/ordination
# Out:
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/biom/table.py:4068: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return constructor(mat, index=index, columns=columns)
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/pandas/core/sparse/frame.py:257: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   sparse_index=BlockIndex(N, blocs, blens),
# ...

# %%
    --num-testing-examples 16\
    --input-prior 1.0\
    --output-prior 1.0\
    --learning-rate 1e-5\
    --beta1 0.9\
    --beta2 0.95\
    --clipnorm 10.0\
